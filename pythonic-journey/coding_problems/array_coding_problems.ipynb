# %% [markdown]
# SECOND LARGEST ELEMENT IN AN ARRAY
#
# Given an array of positive integers arr[] of size n, The task is to find second largest distinct element in an array.
#
# Note: If the second largest element does not exist, return -1

# %% [markdown]
# 1. Input: arr[] = [12, 35, 1, 10, 34, 1]
#     output: 34
#
# 2. Input: arr[] = [10,1,10]
#     output : 1
#
# 3. Input: arr[] = [10,10,10]
#     output : -1

# %%
arr = [12,35,1,10,34,1]
print("Original array:", arr)

first_larger_num = 0
second_large_num = 0
sorted_arr = sorted(arr)
print("Sorted array:", sorted_arr)

if len(sorted_arr) <= 2:
    print("Array does not have enough elements to find the second largest number.")
else:
    for i in range(len(arr)-1, -1, -1):
        first_larger_num = sorted_arr[i]
        second_large_num = sorted_arr[i-1]
        print("First larger number:", first_larger_num)
        print("Second larger number:", second_large_num)

        if first_larger_num == second_large_num:
            second_large_num = sorted_arr[i-2]
            print("Second larger number:", second_large_num)
        else:
            return print("-1")

prnt("Second largest number:", second_large_num)
# Out:
# Original array: [12, 35, 1, 10, 34, 1]
# Sorted array: [1, 1, 10, 12, 34, 35]
#   Cell In[6], line 22
#     return print("-1")
#     ^
# SyntaxError: 'return' outside function
